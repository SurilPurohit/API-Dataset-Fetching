# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=a91e384aa21a2e5a13c973706377cf4e&include_video=false&language=en-US&page=1&sort_by=popularity.desc')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['adult', 'id', 'original_language', 'overview', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]

# %%
temp_df
# Out:
#     adult       id original_language  \
# 0   False   823464                en
# 1   False  1094844                en
# 2   False   693134                en
# 3   False  1096197                en
# 4   False  1011985                en
# 5   False   934632                en
# 6   False  1041613                en
# 7   False   821937                vi
# 8   False   845111                fr
# 9   False   748783                en
# 10  False   940721                ja
# 11  False   653346                en
# 12  False  1063879                fr
# 13  False   976906                en
# 14  False   618588                en
# 15  False   634492                en
# 16  False   359410                en
# 17  False   872585                en
# 18  False   940551                en
# 19  False   784651                hi
#
#                                              overview  popularity  \
# 0   Following their explosive showdown, Godzilla a...    1818.259
# ...

# %%
temp_df.set_index('id', inplace=True)

# %%
temp_df
# Out:
#          adult original_language  \
# id
# 823464   False                en
# 1094844  False                en
# 693134   False                en
# 1096197  False                en
# 1011985  False                en
# 934632   False                en
# 1041613  False                en
# 821937   False                vi
# 845111   False                fr
# 748783   False                en
# 940721   False                ja
# 653346   False                en
# 1063879  False                fr
# 976906   False                en
# 618588   False                en
# 634492   False                en
# 359410   False                en
# 872585   False                en
# 940551   False                en
# 784651   False                hi
#
#                                                   overview  popularity  \
# id
# 823464   Following their explosive showdown, Godzilla a...    1818.259
# 1094844  Recognizing the destructive power of its capti...    1639.584
# ...

# %%
df = pd.DataFrame()
for i in range(1,501):
    response = requests.get(f'https://api.themoviedb.org/3/discover/movie?api_key=a91e384aa21a2e5a13c973706377cf4e&include_video=false&language=en-US&page={i}&sort_by=popularity.desc')
    temp_df = pd.DataFrame(response.json()['results'])
    df = df._append(temp_df,ignore_index=True)

# %%
df.head()
# Out:
#    adult                     backdrop_path                genre_ids       id  \
# 0  False  /qrGtVFxaD8c7et0jUtaYhyTzzPg.jpg            [28, 878, 12]   823464
# 1  False  /jnE1GA7cGEfv5DJBoU2t4bZHaP4.jpg                [28, 878]  1094844
# 2  False  /xOMo8BRK7PfcJv9JCnx7s5hj0PX.jpg                [878, 12]   693134
# 3  False  /4woSOUD0equAYzvwhWBHIJDCM88.jpg             [28, 27, 53]  1096197
# 4  False  /kYgQzzjNis5jJalYtIHgrom0gOx.jpg  [16, 28, 10751, 35, 14]  1011985
#
#   original_language                   original_title  \
# 0                en  Godzilla x Kong: The New Empire
# 1                en                Ape vs. Mecha Ape
# 2                en                   Dune: Part Two
# 3                en                        No Way Up
# 4                en                  Kung Fu Panda 4
#
#                                             overview  popularity  \
# 0  Following their explosive showdown, Godzilla a...    1818.259
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.drop(['backdrop_path', 'genre_ids', 'poster_path', 'video'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              10000 non-null  bool
#  1   id                 10000 non-null  int64
#  2   original_language  10000 non-null  object
#  3   original_title     10000 non-null  object
#  4   overview           10000 non-null  object
#  5   popularity         10000 non-null  float64
#  6   release_date       10000 non-null  object
#  7   title              10000 non-null  object
#  8   vote_average       10000 non-null  float64
#  9   vote_count         10000 non-null  int64
# dtypes: bool(1), float64(2), int64(2), object(5)
# memory usage: 713.0+ KB

# %%
df.head()
# Out:
#    adult       id original_language                   original_title  \
# 0  False   823464                en  Godzilla x Kong: The New Empire
# 1  False  1094844                en                Ape vs. Mecha Ape
# 2  False   693134                en                   Dune: Part Two
# 3  False  1096197                en                        No Way Up
# 4  False  1011985                en                  Kung Fu Panda 4
#
#                                             overview  popularity release_date  \
# 0  Following their explosive showdown, Godzilla a...    1818.259   2024-03-27
# 1  Recognizing the destructive power of its capti...    1639.584   2023-03-24
# 2  Follow the mythic journey of Paul Atreides as ...    1390.639   2024-02-27
# 3  Characters from different backgrounds are thro...    1245.817   2024-01-18
# 4  Po is gearing up to become the spiritual leade...    1230.013   2024-03-02
#
#                              title  vote_average  vote_count
# ...

# %%
file_path = 'movie-dataset.csv'

df.to_csv(file_path, index=False)

print(f"CSV file saved successfully to '{file_path}'")
# Out:
# CSV file saved successfully to 'movie-dataset.csv'
